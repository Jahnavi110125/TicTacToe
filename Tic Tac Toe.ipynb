# %%
user1 = input("Enter player1 name  ")
user2 = input("Enter player2 name  ")
import numpy as np
def tic(board,n):
    win = False
    while win == False:
        win = tica(board, win,n)
        if win == True:
            print(user1+" own the game")
            break
        win = ticb(board, win,n)
        if win == True:
            print(user2+" own the game")
            break
    
def tica(board,win,n):
    l1 = ['x','o','X','O']
    countr1 = countr2 = countc1 = countc2 = d1 = d2 = d3 = d4 = 0
    print("Its "+user1+" turn")
    print()
    print("Please enter 'x' or 'o' ")
    u1 = input()
    while u1 not in l1:
        print("Invalid charecter")
        print("Please enter 'x' or 'o' ")
        u1 = input()
    print("Please enter row and column numbers (0 to 3) (0 to 3)")
    r1,c1 = list(map(int,input().split()))
    print()
    while c1 >=n or r1 >= n:
        print("Invalid place")
        print("Please enter row and column numbers (0 to 3) (0 to 3)")
        r1,c1 = list(map(int,input().split()))
        print()

    if board[r1][c1] == 0:
        board[r1][c1] = u1
        printboard(board,n)
    else:
        while board[r1][c1] != 0:
            print("Please choose appropiate place")
            r1,c1 = list(map(int,input().split()))
        board[r1][c1] = u1
        printboard(board,n)
        
    for i in range(n):
        if board[r1][i] == 'x' or board[r1][i] == 'X':
            countr1 +=1
       
        if board[r1][i] == 'o' or board[r1][i] == 'O':
            countr2 +=1
        
        if board[i][c1] == 'x' or board[i][c1] == 'X':
            countc1 +=1
        
        if board[i][c1] == 'o' or board[i][c1] == 'O':
            countc2 +=1
        
    for i in range(n):
        for j in range(n):
            if i == j:
                if board[i][j] == 'x' or board[i][j] == 'X':
                    d1 += 1
                if board[i][j] == 'o' or board[i][j] == 'O':
                    d2 += 1
            if i+j == (n-1):
                if board[i][j] == 'x' or board[i][j] == 'X':
                    d3 += 1
                if board[i][j] == 'o' or board[i][j] == 'O':
                    d4 += 1
    if d1 == n or d2 == n or d3 == n or d4 == n or countr1 == n or countr2 == n or countc1 == n or countc2 == n:
        win = True
    return win
       
def ticb(board,win,n):
    l1 = ['x','o','X','O']
    countr1 = countr2 = countc1 = countc2 = d1 = d2 = d3 = d4 = 0
    print("Its "+user2+" turn")
    print()
    print("Please enter 'x' or 'o' ")
    u2 = input()
    while u2 not in l1:
        print("Invalid charecter")
        print("Please enter 'x' or 'o' ")
        u2 = input()
    print("Please enter row and column numbers (0 to 3) (0 to 3)")
    r2,c2 = list(map(int,input().split()))
    print()

    while c2 >=n or r2>= n:
        print("Invalid place")
        print("Please enter row and column numbers (0 to 3) (0 to 3)")
        r2,c2 = list(map(int,input().split()))
        print()
    if board[r2][c2] == 0:
        board[r2][c2] = u2
        printboard(board,n)
    else:
        while board[r2][c2] != 0:
            print("Please choose appropiate place")
            r2,c2 = list(map(int,input().split()))
        board[r2][c2] = u2
        printboard(board,n)
    for i in range(n):
        if board[r2][i] == 'x' or board[r2][i] == 'X':
            countr1 +=1
            
       
        if board[r2][i] == 'o' or board[r2][i] == 'O':
            countr2 +=1
    
        if board[i][c2] == 'x' or board[i][c2] == 'X':
            countc1 +=1
       
        if board[i][c2] == 'o' or board[i][c2] == 'O':
            countc2 +=1
    
    for i in range(n):
        for j in range(n):
            if i == j:
                if board[i][j] == 'x' or board[i][j] == 'X':
                    d1 += 1
                if board[i][j] == 'o' or board[i][j] == 'O':
                    d2 += 1
            if i+j == (n-1):
                if board[i][j] == 'x' or board[i][j] == 'X':
                    d3 += 1
                if board[i][j] == 'o' or board[i][j] == 'O':
                    d4 += 1
    if d1 == n or d2 == n or d3 == n or d4 == n or countr1 == n or countr2 == n or countc1 == n or countc2 == n:
        win = True
    return win
            
def printboard(board,n):
    for i in range(n):
        for j in range(n):
            print(board[i][j],end=" | ")
        print()
        print("-"*((n*4)-1))
    print("_________________________________")
    
    
n = int(input("Enter board size"))
print()
board = [[0 for i in range(n)]for j in range(n)]
tic(board,n)
# Out:
# Enter player1 name  A
# Enter player2 name  B
# Enter board size3
#
# Its A turn
#
# Please enter 'x' or 'o'
# X
# Please enter row and column numbers (0 to 3) (0 to 3)
# 0 0
#
# X | 0 | 0 |
# -----------
# 0 | 0 | 0 |
# -----------
# 0 | 0 | 0 |
# -----------
# _________________________________
# Its B turn
#
# Please enter 'x' or 'o'
# X
# Please enter row and column numbers (0 to 3) (0 to 3)
# 1 1
#
# X | 0 | 0 |
# -----------
# 0 | X | 0 |
# -----------
# 0 | 0 | 0 |
# -----------
# _________________________________
# Its A turn
#
# Please enter 'x' or 'o'
# X
# Please enter row and column numbers (0 to 3) (0 to 3)
# 2 2
#
# X | 0 | 0 |
# -----------
# 0 | X | 0 |
# -----------
# 0 | 0 | X |
# -----------
# _________________________________
# A own the game

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\JAHNAVI'
